# %%
import pandas

# %%
df = pandas.read_csv('years.csv')

# %%
df
# Out:
#     year   USA  Russia/USSR  China   ROK
# 0   1980  77.2          7.9   78.6  43.1
# 1   1981  69.4          7.2   68.3  34.5
# 2   1982  71.4          8.0   72.7  40.2
# 3   1983  71.9          8.9   72.5  39.0
# 4   1984  74.9          7.7   74.4  43.6
# 5   1985  75.6          8.6   75.4  45.4
# 6   1986  67.5          8.9   68.6  39.7
# 7   1987  72.2          9.8   69.3  42.2
# 8   1988  73.6         14.0   68.5  50.9
# 9   1989  76.4         13.2   51.6  40.7
# 10  1990  74.2         23.3   52.3  42.7
# 11  1991  78.1         25.3   51.1  43.1
# 12  1992  73.7         15.1   55.5  42.9
# 13  1993  76.3         11.0   53.8  43.4
# 14  1994  73.6         11.7   51.3  41.9
# 15  1995  71.2          9.9   48.4  42.2
# 16  1996  75.3         10.4   45.0  35.8
# 17  1997  73.9         11.2   45.9  37.9
# 18  1998  77.6         14.9   48.9  46.2
# 19  1999  75.6         15.8   49.6  48.3
# 20  2000  73.8         14.2   48.8  51.4
# 21  2001  76.5         17.9   47.5  50.3
# 22  2002  75.6         15.1   45.6  54.2
# 23  2003  75.8         20.0   47.9  55.0
# 24  2004  71.8         16.3   37.6  56.7
# 25  2005  73.2         16.2   32.4  51.1
# 26  2006  75.3         15.4   34.3  48.5
# 27  2007  75.6         14.7   34.0  54.8
# 28  2008  73.3         13.0   31.8  57.1
# 29  2009  78.9         15.4   38.5  63.1
# 30  2010  79.9         14.0   20.0  61.8
# 31  2011  82.0         13.4   26.3  62.2
# 32  2012  84.5         19.5   18.0  39.2
# 33  2013  83.1         22.5   18.1  40.7
# 34  2014  82.6         20.1   14.8  31.5
# 35  2015  84.4         17.4   14.8  33.0
# 36  2016  84.1         19.3   16.8  38.1
# 37  2017  78.4         18.0   18.7  37.7
# 38  2018  75.5         17.7   20.8  39.4
# 39  2019  78.7         20.8   22.7  26.7
# 40  2020  84.0         13.6   22.0  34.9
# 41  2021  88.5         13.1   20.6  37.0
# 42  2022  87.2          5.0   17.8  45.9

# %%
df.plot(x='year',y=['USA','China','Russia/USSR','ROK'])
# Out:
# <Axes: xlabel='year'>

# %%
df = pandas.read_csv('gender.csv')

# %%
df
# Out:
#   country  gender  percent
# 0     USA    male     90.1
# 1   China    male     17.7
# 2   Korea    male     38.9
# 3  Russia    male      5.7
# 4     USA  female     84.6
# 5   China  female     17.9
# 6   Korea  female     52.1
# 7  Russia  female      4.5

# %%
df.dtypes
# Out:
# country     object
# gender      object
# percent    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  8 non-null      object
#  1   gender   8 non-null      object
#  2   percent  8 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.plot(kind='scatter',x='percent',y='country')
# Out:
# <Axes: xlabel='percent', ylabel='country'>

# %%
df = pandas.read_csv('age.csv')

# %%
df
# Out:
#    country          age  percent
# 0      USA     under 30     86.0
# 1    China     under 30     28.0
# 2    Korea     under 30     64.7
# 3   Russia     under 30      6.7
# 4      USA          30s     81.6
# 5    China          30s     23.7
# 6    Korea          30s     54.7
# 7   Russia          30s      7.9
# 8      USA          40s     84.5
# 9    China          40s     19.2
# 10   Korea          40s     41.9
# 11  Russia          40s      4.9
# 12     USA          50s     89.9
# 13   China          50s     16.8
# 14   Korea          50s     46.5
# 15  Russia          50s      7.9
# 16     USA          60s     89.5
# 17   China          60s     12.8
# 18   Korea          60s     45.2
# 19  Russia          60s      2.6
# 20     USA  70 and over     87.9
# 21   China  70 and over     15.6
# 22   Korea  70 and over     39.1
# 23  Russia  70 and over      3.2

# %%
df.plot(kind='scatter',x='percent',y='country')
# Out:
# <Axes: xlabel='percent', ylabel='country'>
